# %% [markdown]
# #Processing of the MQ sensors' logs

# %% [markdown]
# In this **project**, we'll build a neural network and use it to predict food quality.

# %%
#Importing modules
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Load and prepare the data
#
# A critical step in working with neural networks is preparing the data correctly.

# %%
data_path = 'mq_sensors_logs_feta.csv'

df_feta = pd.read_csv(data_path)
# Watch all columns
pd.options.display.max_columns = None

# Add value 0 for first day and 1 for rest.
df_feta.loc[0:1440, 'day'] = 0
df_feta.loc[1440:, 'day'] = 1

#rides_feta.head(10)
print(df_feta[1438:1450])
# Out:
#       Timestamp  Raw_value_MQ2  Raw_value_MQ3  Raw_value_MQ4  Raw_value_MQ135  \
# 1438       1445         1728.0         2752.0         1088.0           1152.0
# 1439       1446         1728.0         3328.0         1088.0           1152.0
# 1440       1447         1728.0         2880.0         1088.0           1152.0
# 1441       1448         1728.0         3136.0         1088.0           1152.0
# 1442       1449         1728.0         2688.0         1088.0           1152.0
# 1443       1450         1728.0         2944.0         1088.0           1152.0
# 1444       1451         1728.0         2918.4         1088.0           1152.0
# 1445       1452         1728.0         2956.8         1088.0           1152.0
# 1446       1453         1728.0         2944.0         1088.0           1152.0
# 1447       1454         1728.0         2496.0         1088.0           1152.0
# 1448       1455         1728.0         2752.0         1088.0           1152.0
# 1449       1456         1728.0         2944.0         1088.0           1139.2
#
#       Raw_value_MQ6  Raw_value_MQ7  Raw_value_MQ8  Raw_value_MQ9      day
# 1438         1216.0         1792.0         1702.4         1216.0 NaN  0.0
# 1439         1216.0         1792.0         1728.0         1216.0 NaN  0.0
# 1440         1216.0         1792.0         1715.2         1216.0 NaN  1.0
# 1441         1216.0         1792.0         1702.4         1216.0 NaN  1.0
# 1442         1216.0         1792.0         1702.4         1216.0 NaN  1.0
# 1443         1216.0         1792.0         1702.4         1216.0 NaN  1.0
# 1444         1216.0         1792.0         1715.2         1216.0 NaN  1.0
# 1445         1216.0         1792.0         1702.4         1216.0 NaN  1.0
# 1446         1216.0         1792.0         1702.4         1216.0 NaN  1.0
# 1447         1216.0         1792.0         1702.4         1216.0 NaN  1.0
# 1448         1216.0         1792.0         1728.0         1216.0 NaN  1.0
# 1449         1216.0         1792.0         1676.8         1216.0 NaN  1.0

# %% [markdown]
# ##Checking out the data
# This dataset has logs from various different simple air sensors that are collected during food degradation over a period of time. Logs are collected in intervals of 1 minute so for one day we have 1440 entries. Check the basic set up for the [MQ-2 sensor](https://medium.com/p/5c7e2338267f) and the whole [bunch of air sensors](https://medium.com/p/b4523540f63d).

# %%
df_feta[:7000].plot(x='Timestamp', y='Raw_value_MQ2')

# %% [markdown]
# ##Normalizing the values
# We are dividing every log by 65472 wich is the maximum value each sensor can give. For more info read [this](https://github.com/adafruit/Adafruit_CircuitPython_MCP3xxx/blob/main/adafruit_mcp3xxx/analog_in.py#L50-L54).

# %%
sensor_names = ['Raw_value_MQ2', 'Raw_value_MQ3', 'Raw_value_MQ4', 'Raw_value_MQ135', 'Raw_value_MQ6', 'Raw_value_MQ7', 'Raw_value_MQ8', 'Raw_value_MQ9']
sensor_names_with_day = ['Raw_value_MQ2', 'Raw_value_MQ3', 'Raw_value_MQ4', 'Raw_value_MQ135', 'Raw_value_MQ6', 'Raw_value_MQ7', 'Raw_value_MQ8', 'Raw_value_MQ9', 'day']

MAX_VALUE = 65472
for each in sensor_names:
    df_feta.loc[:, each] = df_feta[each] / MAX_VALUE

df_feta[:10]
# Out:
#    Timestamp  Raw_value_MQ2  Raw_value_MQ3  Raw_value_MQ4  Raw_value_MQ135  \
# 0          0       0.024829       0.098729        0.01564         0.017595
# 1          1       0.024438       0.087977        0.01564         0.017595
# 2          2       0.024438       0.090714        0.01564         0.017400
# 3          3       0.024438       0.080352        0.01564         0.017595
# 4          4       0.024438       0.077419        0.01564         0.017595
# 5          5       0.024438       0.084066        0.01564         0.017400
# 6          6       0.024438       0.089932        0.01564         0.017400
# 7          7       0.024438       0.102639        0.01564         0.017400
# 8          8       0.024438       0.091691        0.01564         0.017400
# 9          9       0.024438       0.095015        0.01564         0.017595
#
#    Raw_value_MQ6  Raw_value_MQ7  Raw_value_MQ8  Raw_value_MQ9      day
# 0       0.018573       0.028348       0.025415       0.019550 NaN  0.0
# 1       0.018573       0.028348       0.025415       0.019550 NaN  0.0
# 2       0.018573       0.028348       0.025611       0.019550 NaN  0.0
# 3       0.018573       0.028348       0.025806       0.018768 NaN  0.0
# 4       0.018573       0.028543       0.026197       0.019159 NaN  0.0
# 5       0.018573       0.028348       0.026393       0.018573 NaN  0.0
# 6       0.018573       0.028348       0.026002       0.018573 NaN  0.0
# 7       0.018573       0.028348       0.026393       0.019550 NaN  0.0
# 8       0.018573       0.028348       0.026197       0.018964 NaN  0.0
# 9       0.018573       0.028348       0.026393       0.019550 NaN  0.0

# %%
df_feta[:7000].plot(x='Timestamp', y='Raw_value_MQ2')

# %%
fields = df_feta[sensor_names_with_day]

# %%
fields[1438:1450]
# Out:
#       Raw_value_MQ2  Raw_value_MQ3  Raw_value_MQ4  Raw_value_MQ135  \
# 1438       0.026393       0.042033       0.016618         0.017595
# 1439       0.026393       0.050831       0.016618         0.017595
# 1440       0.026393       0.043988       0.016618         0.017595
# 1441       0.026393       0.047898       0.016618         0.017595
# 1442       0.026393       0.041056       0.016618         0.017595
# 1443       0.026393       0.044966       0.016618         0.017595
# 1444       0.026393       0.044575       0.016618         0.017595
# 1445       0.026393       0.045161       0.016618         0.017595
# 1446       0.026393       0.044966       0.016618         0.017595
# 1447       0.026393       0.038123       0.016618         0.017595
# 1448       0.026393       0.042033       0.016618         0.017595
# 1449       0.026393       0.044966       0.016618         0.017400
#
#       Raw_value_MQ6  Raw_value_MQ7  Raw_value_MQ8  Raw_value_MQ9  day
# 1438       0.018573        0.02737       0.026002       0.018573  0.0
# 1439       0.018573        0.02737       0.026393       0.018573  0.0
# 1440       0.018573        0.02737       0.026197       0.018573  1.0
# 1441       0.018573        0.02737       0.026002       0.018573  1.0
# 1442       0.018573        0.02737       0.026002       0.018573  1.0
# 1443       0.018573        0.02737       0.026002       0.018573  1.0
# 1444       0.018573        0.02737       0.026197       0.018573  1.0
# 1445       0.018573        0.02737       0.026002       0.018573  1.0
# 1446       0.018573        0.02737       0.026002       0.018573  1.0
# 1447       0.018573        0.02737       0.026002       0.018573  1.0
# 1448       0.018573        0.02737       0.026393       0.018573  1.0
# 1449       0.018573        0.02737       0.025611       0.018573  1.0

# %% [markdown]
# ### Splitting the data into training, testing, and validation sets
#
# We'll save the data for the first 50 minutes of each day as test set and split the rest as training and validation sets.

# %%
# Test data for 100 minutes
test_data_first_day = fields[0:50]
test_data_second_day = fields[1440:1490]
test_data_two_days = [test_data_first_day, test_data_second_day]
# we DO NOT shuffle the test set
test_data = pd.concat(test_data_two_days)


# Now remove the test data from the data set (USE VALUES UNTIL 3000 ENTRIES)
data_first_day = fields[50:1440]
data_second_day = fields[1490:3000]
data_two_days = [data_first_day, data_second_day]
data_rest = pd.concat(data_two_days)
#print(data_rest[:10])
# SHUFFLE the dataset before splitting into training and validation and reset the index
data_rest = data_rest.sample(frac=1).reset_index(drop=True)
print(data_rest[:10])

# Separate the data into features and targets
target_field = ['day']
data_features, data_targets = data_rest.drop(target_field, axis=1), data_rest[target_field]
test_features, test_targets = test_data.drop(target_field, axis=1), test_data[target_field]
# Out:
#    Raw_value_MQ2  Raw_value_MQ3  Raw_value_MQ4  Raw_value_MQ135  \
# 0       0.028935       0.036950       0.017595         0.017204
# 1       0.027566       0.037928       0.017204         0.017595
# 2       0.026393       0.049853       0.016618         0.017595
# 3       0.026393       0.049267       0.016618         0.017595
# 4       0.029130       0.035191       0.017595         0.017009
# 5       0.028739       0.037146       0.017595         0.017400
# 6       0.025415       0.096383       0.015640         0.017595
# 7       0.028348       0.036168       0.017595         0.017595
# 8       0.028348       0.035191       0.017595         0.017595
# 9       0.026393       0.049853       0.016618         0.017595
#
#    Raw_value_MQ6  Raw_value_MQ7  Raw_value_MQ8  Raw_value_MQ9  day
# 0       0.018573       0.026393       0.025415       0.017986  1.0
# 1       0.018573       0.027370       0.026002       0.018573  1.0
# 2       0.018573       0.027370       0.025806       0.018573  1.0
# 3       0.018573       0.027370       0.025611       0.018573  0.0
# 4       0.018573       0.026393       0.025415       0.017791  1.0
# 5       0.018573       0.026393       0.025415       0.018377  1.0
# 6       0.018573       0.028348       0.026393       0.018573  0.0
# 7       0.018573       0.026393       0.025415       0.018377  1.0
# 8       0.018573       0.026393       0.025415       0.018377  1.0
# 9       0.018573       0.027370       0.026002       0.018573  0.0

# %%
# Create test features list.
test_features_list=[]

for row in test_features.iterrows():
    index, data = row
    test_features_list.append(data.tolist())

# Create test targets list.
test_targets_list=[]

for row in test_targets.iterrows():
    index, data = row
    test_targets_list.append(data.tolist())


# Create data features list.
data_features_list=[]

for row in data_features.iterrows():
    index, data = row
    data_features_list.append(data.tolist())

# Create data targets list.
data_targets_list=[]

for row in data_targets.iterrows():
    index, data = row
    data_targets_list.append(data.tolist())

# %%
'''
print(data_features_list[:10])
print(data_targets_list[:10])
print(len(data_targets_list))
'''
# Out:
# '\nprint(data_features_list[:10])\nprint(data_targets_list[:10])\nprint(len(data_targets_list))\n'

# %%
# Split into training and validation data
# Hold out the last 500 entries or so of the remaining data as a validation set
train_features, train_targets = np.array(data_features_list[:2400]), np.array(data_targets_list[:2400])
val_features, val_targets = np.array(data_features_list[2400:]), np.array(data_targets_list[2400:])
test_features, test_targets = np.array(test_features_list[:]), np.array(test_targets_list[:])

# %%
'''
print(len(train_features))
print(len(train_targets))


print(len(val_features))
print(len(val_targets))
'''
# Out:
# '\nprint(len(train_features))\nprint(len(train_targets))\n\n\nprint(len(val_features))\nprint(len(val_targets))\n'

# %%
# Convert targets to categorical
import tensorflow as tf

train_targets_categorical = tf.keras.utils.to_categorical(train_targets, dtype ="uint8")
val_targets_categorical = tf.keras.utils.to_categorical(val_targets, dtype ="uint8")
test_targets_categorical = tf.keras.utils.to_categorical(test_targets, dtype ="uint8")

# %%
print(test_targets_categorical[48:53])
# Out:
# [[1 0]
#  [1 0]
#  [0 1]
#  [0 1]
#  [0 1]]

# %% [markdown]
# ##Build a Keras model to train the dataset.

# %%
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout

model=Sequential()
model.add(Dense(256, input_dim=8,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(2))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               2304
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 43,586
# Trainable params: 43,586
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from tensorflow.keras.optimizers import Adam


adam = Adam(learning_rate=0.000001)
# https://keras.io/api/losses/probabilistic_losses/#categorical_crossentropy-function
model.compile(loss='categorical_crossentropy', 
             optimizer=adam, 
             metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint  

batch_size = 50
num_epochs = 500

checkpoint = ModelCheckpoint(filepath='food_quality.weights.best.h5', verbose=1, 
                               save_best_only=True)

callbacks_list = [checkpoint]

history = model.fit(train_features, train_targets_categorical, validation_data=(val_features, val_targets_categorical), batch_size=batch_size, epochs=num_epochs, callbacks=callbacks_list)
# Out:
# Epoch 1/500
# 43/48 [=========================>....] - ETA: 0s - loss: 1.6966 - accuracy: 0.4874
# Epoch 1: val_loss improved from inf to 0.69027, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 1s 9ms/step - loss: 1.6604 - accuracy: 0.4900 - val_loss: 0.6903 - val_accuracy: 0.4760
# Epoch 2/500
# 31/48 [==================>...........] - ETA: 0s - loss: 1.6150 - accuracy: 0.4794
# Epoch 2: val_loss improved from 0.69027 to 0.67257, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 1.5699 - accuracy: 0.4783 - val_loss: 0.6726 - val_accuracy: 0.4760
# Epoch 3/500
# 34/48 [====================>.........] - ETA: 0s - loss: 1.3376 - accuracy: 0.5018
# Epoch 3: val_loss improved from 0.67257 to 0.66232, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 1.3150 - accuracy: 0.5050 - val_loss: 0.6623 - val_accuracy: 0.4760
# Epoch 4/500
# 48/48 [==============================] - ETA: 0s - loss: 1.2105 - accuracy: 0.5154
# Epoch 4: val_loss improved from 0.66232 to 0.65347, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 1.2105 - accuracy: 0.5154 - val_loss: 0.6535 - val_accuracy: 0.4760
# Epoch 5/500
# 35/48 [====================>.........] - ETA: 0s - loss: 1.1743 - accuracy: 0.5143
# Epoch 5: val_loss improved from 0.65347 to 0.64806, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 1.1760 - accuracy: 0.5179 - val_loss: 0.6481 - val_accuracy: 0.4760
# Epoch 6/500
# 38/48 [======================>.......] - ETA: 0s - loss: 1.0930 - accuracy: 0.5326
# Epoch 6: val_loss improved from 0.64806 to 0.64171, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 1.0594 - accuracy: 0.5304 - val_loss: 0.6417 - val_accuracy: 0.4760
# Epoch 7/500
# 35/48 [====================>.........] - ETA: 0s - loss: 1.0149 - accuracy: 0.5211
# Epoch 7: val_loss improved from 0.64171 to 0.63718, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 1.0094 - accuracy: 0.5279 - val_loss: 0.6372 - val_accuracy: 0.4760
# Epoch 8/500
# 36/48 [=====================>........] - ETA: 0s - loss: 0.9734 - accuracy: 0.5389
# Epoch 8: val_loss improved from 0.63718 to 0.63332, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.9569 - accuracy: 0.5321 - val_loss: 0.6333 - val_accuracy: 0.4760
# Epoch 9/500
# 31/48 [==================>...........] - ETA: 0s - loss: 0.8989 - accuracy: 0.5355
# Epoch 9: val_loss improved from 0.63332 to 0.63263, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.8835 - accuracy: 0.5437 - val_loss: 0.6326 - val_accuracy: 0.4760
# Epoch 10/500
# 37/48 [======================>.......] - ETA: 0s - loss: 0.9226 - accuracy: 0.5476
# Epoch 10: val_loss improved from 0.63263 to 0.63057, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.9295 - accuracy: 0.5425 - val_loss: 0.6306 - val_accuracy: 0.4760
# Epoch 11/500
# 32/48 [===================>..........] - ETA: 0s - loss: 0.8061 - accuracy: 0.5550
# Epoch 11: val_loss improved from 0.63057 to 0.62845, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.8041 - accuracy: 0.5629 - val_loss: 0.6284 - val_accuracy: 0.4760
# Epoch 12/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.8184 - accuracy: 0.5374
# Epoch 12: val_loss improved from 0.62845 to 0.62636, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.8147 - accuracy: 0.5367 - val_loss: 0.6264 - val_accuracy: 0.5280
# Epoch 13/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.8537 - accuracy: 0.5566
# Epoch 13: val_loss improved from 0.62636 to 0.62443, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.8556 - accuracy: 0.5596 - val_loss: 0.6244 - val_accuracy: 0.6060
# Epoch 14/500
# 37/48 [======================>.......] - ETA: 0s - loss: 0.8614 - accuracy: 0.5600
# Epoch 14: val_loss improved from 0.62443 to 0.62285, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.8433 - accuracy: 0.5663 - val_loss: 0.6228 - val_accuracy: 0.8060
# Epoch 15/500
# 36/48 [=====================>........] - ETA: 0s - loss: 0.8448 - accuracy: 0.5733
# Epoch 15: val_loss improved from 0.62285 to 0.62132, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.8485 - accuracy: 0.5633 - val_loss: 0.6213 - val_accuracy: 0.8600
# Epoch 16/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.8284 - accuracy: 0.5434
# Epoch 16: val_loss improved from 0.62132 to 0.62020, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.8337 - accuracy: 0.5421 - val_loss: 0.6202 - val_accuracy: 0.8600
# Epoch 17/500
# 37/48 [======================>.......] - ETA: 0s - loss: 0.7993 - accuracy: 0.5795
# Epoch 17: val_loss improved from 0.62020 to 0.61866, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.8270 - accuracy: 0.5725 - val_loss: 0.6187 - val_accuracy: 0.8760
# Epoch 18/500
# 33/48 [===================>..........] - ETA: 0s - loss: 0.8067 - accuracy: 0.5533
# Epoch 18: val_loss improved from 0.61866 to 0.61742, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7855 - accuracy: 0.5575 - val_loss: 0.6174 - val_accuracy: 0.8920
# Epoch 19/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.8101 - accuracy: 0.5697
# Epoch 19: val_loss improved from 0.61742 to 0.61599, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7900 - accuracy: 0.5788 - val_loss: 0.6160 - val_accuracy: 0.9040
# Epoch 20/500
# 36/48 [=====================>........] - ETA: 0s - loss: 0.7839 - accuracy: 0.5600
# Epoch 20: val_loss improved from 0.61599 to 0.61467, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7854 - accuracy: 0.5667 - val_loss: 0.6147 - val_accuracy: 0.9160
# Epoch 21/500
# 36/48 [=====================>........] - ETA: 0s - loss: 0.7670 - accuracy: 0.5961
# Epoch 21: val_loss improved from 0.61467 to 0.61308, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7624 - accuracy: 0.5896 - val_loss: 0.6131 - val_accuracy: 0.9280
# Epoch 22/500
# 33/48 [===================>..........] - ETA: 0s - loss: 0.7186 - accuracy: 0.5891
# Epoch 22: val_loss improved from 0.61308 to 0.61154, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7095 - accuracy: 0.5992 - val_loss: 0.6115 - val_accuracy: 0.9360
# Epoch 23/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.7241 - accuracy: 0.5851
# Epoch 23: val_loss improved from 0.61154 to 0.61026, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7278 - accuracy: 0.5696 - val_loss: 0.6103 - val_accuracy: 0.9380
# Epoch 24/500
# 36/48 [=====================>........] - ETA: 0s - loss: 0.7901 - accuracy: 0.5739
# Epoch 24: val_loss improved from 0.61026 to 0.60899, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7667 - accuracy: 0.5783 - val_loss: 0.6090 - val_accuracy: 0.9340
# Epoch 25/500
# 37/48 [======================>.......] - ETA: 0s - loss: 0.7763 - accuracy: 0.5946
# Epoch 25: val_loss improved from 0.60899 to 0.60887, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7610 - accuracy: 0.5983 - val_loss: 0.6089 - val_accuracy: 0.8960
# Epoch 26/500
# 33/48 [===================>..........] - ETA: 0s - loss: 0.7402 - accuracy: 0.6030
# Epoch 26: val_loss improved from 0.60887 to 0.60773, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7299 - accuracy: 0.6058 - val_loss: 0.6077 - val_accuracy: 0.8920
# Epoch 27/500
# 31/48 [==================>...........] - ETA: 0s - loss: 0.6734 - accuracy: 0.6110
# Epoch 27: val_loss improved from 0.60773 to 0.60684, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6929 - accuracy: 0.6025 - val_loss: 0.6068 - val_accuracy: 0.8860
# Epoch 28/500
# 38/48 [======================>.......] - ETA: 0s - loss: 0.7460 - accuracy: 0.6089
# Epoch 28: val_loss improved from 0.60684 to 0.60614, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7512 - accuracy: 0.6179 - val_loss: 0.6061 - val_accuracy: 0.8640
# Epoch 29/500
# 36/48 [=====================>........] - ETA: 0s - loss: 0.6842 - accuracy: 0.5928
# Epoch 29: val_loss did not improve from 0.60614
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6997 - accuracy: 0.5900 - val_loss: 0.6070 - val_accuracy: 0.9040
# Epoch 30/500
# 32/48 [===================>..........] - ETA: 0s - loss: 0.7229 - accuracy: 0.5931
# Epoch 30: val_loss did not improve from 0.60614
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7239 - accuracy: 0.5913 - val_loss: 0.6070 - val_accuracy: 0.8520
# Epoch 31/500
# 32/48 [===================>..........] - ETA: 0s - loss: 0.7165 - accuracy: 0.6256
# Epoch 31: val_loss improved from 0.60614 to 0.60613, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.7059 - accuracy: 0.6217 - val_loss: 0.6061 - val_accuracy: 0.8500
# Epoch 32/500
# 34/48 [====================>.........] - ETA: 0s - loss: 0.7073 - accuracy: 0.6135
# Epoch 32: val_loss improved from 0.60613 to 0.60529, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.7138 - accuracy: 0.6108 - val_loss: 0.6053 - val_accuracy: 0.8500
# Epoch 33/500
# 36/48 [=====================>........] - ETA: 0s - loss: 0.7443 - accuracy: 0.6200
# Epoch 33: val_loss improved from 0.60529 to 0.60455, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7319 - accuracy: 0.6129 - val_loss: 0.6045 - val_accuracy: 0.8500
# Epoch 34/500
# 48/48 [==============================] - ETA: 0s - loss: 0.7025 - accuracy: 0.6000
# Epoch 34: val_loss improved from 0.60455 to 0.60426, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.7025 - accuracy: 0.6000 - val_loss: 0.6043 - val_accuracy: 0.8260
# Epoch 35/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.6846 - accuracy: 0.6103
# Epoch 35: val_loss improved from 0.60426 to 0.60340, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6769 - accuracy: 0.6104 - val_loss: 0.6034 - val_accuracy: 0.8280
# Epoch 36/500
# 37/48 [======================>.......] - ETA: 0s - loss: 0.6976 - accuracy: 0.6303
# Epoch 36: val_loss improved from 0.60340 to 0.60335, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7005 - accuracy: 0.6267 - val_loss: 0.6033 - val_accuracy: 0.8060
# Epoch 37/500
# 31/48 [==================>...........] - ETA: 0s - loss: 0.7447 - accuracy: 0.6194
# Epoch 37: val_loss improved from 0.60335 to 0.60300, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.7309 - accuracy: 0.6175 - val_loss: 0.6030 - val_accuracy: 0.7860
# Epoch 38/500
# 32/48 [===================>..........] - ETA: 0s - loss: 0.7062 - accuracy: 0.6231
# Epoch 38: val_loss improved from 0.60300 to 0.60214, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.7109 - accuracy: 0.6187 - val_loss: 0.6021 - val_accuracy: 0.7860
# Epoch 39/500
# 37/48 [======================>.......] - ETA: 0s - loss: 0.6845 - accuracy: 0.6168
# Epoch 39: val_loss improved from 0.60214 to 0.60124, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.7000 - accuracy: 0.6187 - val_loss: 0.6012 - val_accuracy: 0.7860
# Epoch 40/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.6698 - accuracy: 0.6114
# Epoch 40: val_loss improved from 0.60124 to 0.60032, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6612 - accuracy: 0.6129 - val_loss: 0.6003 - val_accuracy: 0.7860
# Epoch 41/500
# 31/48 [==================>...........] - ETA: 0s - loss: 0.6879 - accuracy: 0.6219
# Epoch 41: val_loss improved from 0.60032 to 0.59940, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6981 - accuracy: 0.6233 - val_loss: 0.5994 - val_accuracy: 0.7860
# Epoch 42/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.6834 - accuracy: 0.6269
# Epoch 42: val_loss improved from 0.59940 to 0.59848, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6794 - accuracy: 0.6367 - val_loss: 0.5985 - val_accuracy: 0.7860
# Epoch 43/500
# 43/48 [=========================>....] - ETA: 0s - loss: 0.6894 - accuracy: 0.6284
# Epoch 43: val_loss improved from 0.59848 to 0.59754, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6937 - accuracy: 0.6267 - val_loss: 0.5975 - val_accuracy: 0.7860
# Epoch 44/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.6703 - accuracy: 0.6474
# Epoch 44: val_loss improved from 0.59754 to 0.59650, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6694 - accuracy: 0.6458 - val_loss: 0.5965 - val_accuracy: 0.7880
# Epoch 45/500
# 48/48 [==============================] - ETA: 0s - loss: 0.7138 - accuracy: 0.6217
# Epoch 45: val_loss improved from 0.59650 to 0.59541, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.7138 - accuracy: 0.6217 - val_loss: 0.5954 - val_accuracy: 0.7960
# Epoch 46/500
# 37/48 [======================>.......] - ETA: 0s - loss: 0.6655 - accuracy: 0.6276
# Epoch 46: val_loss improved from 0.59541 to 0.59444, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6608 - accuracy: 0.6258 - val_loss: 0.5944 - val_accuracy: 0.8060
# Epoch 47/500
# 34/48 [====================>.........] - ETA: 0s - loss: 0.6650 - accuracy: 0.6412
# Epoch 47: val_loss improved from 0.59444 to 0.59360, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6743 - accuracy: 0.6358 - val_loss: 0.5936 - val_accuracy: 0.8000
# Epoch 48/500
# 37/48 [======================>.......] - ETA: 0s - loss: 0.6770 - accuracy: 0.6357
# Epoch 48: val_loss improved from 0.59360 to 0.59248, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6903 - accuracy: 0.6313 - val_loss: 0.5925 - val_accuracy: 0.7960
# Epoch 49/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.6953 - accuracy: 0.6229
# Epoch 49: val_loss improved from 0.59248 to 0.59158, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6834 - accuracy: 0.6229 - val_loss: 0.5916 - val_accuracy: 0.8060
# Epoch 50/500
# 33/48 [===================>..........] - ETA: 0s - loss: 0.6789 - accuracy: 0.6152
# Epoch 50: val_loss improved from 0.59158 to 0.59055, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6676 - accuracy: 0.6212 - val_loss: 0.5905 - val_accuracy: 0.8060
# Epoch 51/500
# 48/48 [==============================] - ETA: 0s - loss: 0.6544 - accuracy: 0.6500
# Epoch 51: val_loss improved from 0.59055 to 0.58944, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6544 - accuracy: 0.6500 - val_loss: 0.5894 - val_accuracy: 0.8060
# Epoch 52/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.6847 - accuracy: 0.6434
# Epoch 52: val_loss improved from 0.58944 to 0.58838, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6812 - accuracy: 0.6492 - val_loss: 0.5884 - val_accuracy: 0.8060
# Epoch 53/500
# 34/48 [====================>.........] - ETA: 0s - loss: 0.6963 - accuracy: 0.6565
# Epoch 53: val_loss improved from 0.58838 to 0.58808, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6898 - accuracy: 0.6500 - val_loss: 0.5881 - val_accuracy: 0.7840
# Epoch 54/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.6794 - accuracy: 0.6287
# Epoch 54: val_loss improved from 0.58808 to 0.58683, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6770 - accuracy: 0.6304 - val_loss: 0.5868 - val_accuracy: 0.7840
# Epoch 55/500
# 33/48 [===================>..........] - ETA: 0s - loss: 0.6900 - accuracy: 0.6364
# Epoch 55: val_loss improved from 0.58683 to 0.58586, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6732 - accuracy: 0.6529 - val_loss: 0.5859 - val_accuracy: 0.7840
# Epoch 56/500
# 48/48 [==============================] - ETA: 0s - loss: 0.6662 - accuracy: 0.6546
# Epoch 56: val_loss improved from 0.58586 to 0.58470, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6662 - accuracy: 0.6546 - val_loss: 0.5847 - val_accuracy: 0.7840
# Epoch 57/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.6603 - accuracy: 0.6331
# Epoch 57: val_loss improved from 0.58470 to 0.58344, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6792 - accuracy: 0.6396 - val_loss: 0.5834 - val_accuracy: 0.7840
# Epoch 58/500
# 34/48 [====================>.........] - ETA: 0s - loss: 0.6370 - accuracy: 0.6635
# Epoch 58: val_loss improved from 0.58344 to 0.58212, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6358 - accuracy: 0.6650 - val_loss: 0.5821 - val_accuracy: 0.7840
# Epoch 59/500
# 31/48 [==================>...........] - ETA: 0s - loss: 0.6462 - accuracy: 0.6613
# Epoch 59: val_loss improved from 0.58212 to 0.58083, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6501 - accuracy: 0.6625 - val_loss: 0.5808 - val_accuracy: 0.7840
# Epoch 60/500
# 32/48 [===================>..........] - ETA: 0s - loss: 0.7165 - accuracy: 0.6650
# Epoch 60: val_loss did not improve from 0.58083
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6886 - accuracy: 0.6687 - val_loss: 0.5810 - val_accuracy: 0.7820
# Epoch 61/500
# 33/48 [===================>..........] - ETA: 0s - loss: 0.6815 - accuracy: 0.6497
# Epoch 61: val_loss improved from 0.58083 to 0.57986, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6671 - accuracy: 0.6583 - val_loss: 0.5799 - val_accuracy: 0.7820
# Epoch 62/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.6440 - accuracy: 0.6623
# Epoch 62: val_loss improved from 0.57986 to 0.57870, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6519 - accuracy: 0.6629 - val_loss: 0.5787 - val_accuracy: 0.7840
# Epoch 63/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.6548 - accuracy: 0.6700
# Epoch 63: val_loss improved from 0.57870 to 0.57739, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6589 - accuracy: 0.6692 - val_loss: 0.5774 - val_accuracy: 0.7840
# Epoch 64/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.6419 - accuracy: 0.6366
# Epoch 64: val_loss improved from 0.57739 to 0.57624, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6443 - accuracy: 0.6300 - val_loss: 0.5762 - val_accuracy: 0.7840
# Epoch 65/500
# 37/48 [======================>.......] - ETA: 0s - loss: 0.6443 - accuracy: 0.6757
# Epoch 65: val_loss improved from 0.57624 to 0.57496, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6569 - accuracy: 0.6721 - val_loss: 0.5750 - val_accuracy: 0.7840
# Epoch 66/500
# 34/48 [====================>.........] - ETA: 0s - loss: 0.6867 - accuracy: 0.6735
# Epoch 66: val_loss improved from 0.57496 to 0.57384, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6637 - accuracy: 0.6737 - val_loss: 0.5738 - val_accuracy: 0.7840
# Epoch 67/500
# 32/48 [===================>..........] - ETA: 0s - loss: 0.6418 - accuracy: 0.6681
# Epoch 67: val_loss improved from 0.57384 to 0.57256, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6538 - accuracy: 0.6679 - val_loss: 0.5726 - val_accuracy: 0.7840
# Epoch 68/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.6507 - accuracy: 0.6657
# Epoch 68: val_loss improved from 0.57256 to 0.57131, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6565 - accuracy: 0.6642 - val_loss: 0.5713 - val_accuracy: 0.7840
# Epoch 69/500
# 45/48 [===========================>..] - ETA: 0s - loss: 0.6226 - accuracy: 0.6813
# Epoch 69: val_loss improved from 0.57131 to 0.56999, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6223 - accuracy: 0.6800 - val_loss: 0.5700 - val_accuracy: 0.7860
# Epoch 70/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.6088 - accuracy: 0.6754
# Epoch 70: val_loss improved from 0.56999 to 0.56921, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6196 - accuracy: 0.6796 - val_loss: 0.5692 - val_accuracy: 0.8120
# Epoch 71/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.6401 - accuracy: 0.6731
# Epoch 71: val_loss improved from 0.56921 to 0.56794, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6574 - accuracy: 0.6737 - val_loss: 0.5679 - val_accuracy: 0.8180
# Epoch 72/500
# 48/48 [==============================] - ETA: 0s - loss: 0.6526 - accuracy: 0.6629
# Epoch 72: val_loss improved from 0.56794 to 0.56743, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6526 - accuracy: 0.6629 - val_loss: 0.5674 - val_accuracy: 0.8040
# Epoch 73/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.6388 - accuracy: 0.6877
# Epoch 73: val_loss improved from 0.56743 to 0.56657, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6452 - accuracy: 0.6854 - val_loss: 0.5666 - val_accuracy: 0.7960
# Epoch 74/500
# 48/48 [==============================] - ETA: 0s - loss: 0.6527 - accuracy: 0.6787
# Epoch 74: val_loss improved from 0.56657 to 0.56533, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6527 - accuracy: 0.6787 - val_loss: 0.5653 - val_accuracy: 0.8000
# Epoch 75/500
# 34/48 [====================>.........] - ETA: 0s - loss: 0.6593 - accuracy: 0.6665
# Epoch 75: val_loss improved from 0.56533 to 0.56399, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6560 - accuracy: 0.6600 - val_loss: 0.5640 - val_accuracy: 0.8040
# Epoch 76/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.6431 - accuracy: 0.6800
# Epoch 76: val_loss improved from 0.56399 to 0.56262, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6420 - accuracy: 0.6792 - val_loss: 0.5626 - val_accuracy: 0.8060
# Epoch 77/500
# 36/48 [=====================>........] - ETA: 0s - loss: 0.6517 - accuracy: 0.6656
# Epoch 77: val_loss did not improve from 0.56262
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6401 - accuracy: 0.6725 - val_loss: 0.5643 - val_accuracy: 0.7720
# Epoch 78/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.6137 - accuracy: 0.6757
# Epoch 78: val_loss did not improve from 0.56262
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6139 - accuracy: 0.6742 - val_loss: 0.5630 - val_accuracy: 0.7820
# Epoch 79/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.6126 - accuracy: 0.6829
# Epoch 79: val_loss improved from 0.56262 to 0.56179, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6118 - accuracy: 0.6771 - val_loss: 0.5618 - val_accuracy: 0.7820
# Epoch 80/500
# 36/48 [=====================>........] - ETA: 0s - loss: 0.6376 - accuracy: 0.7000
# Epoch 80: val_loss improved from 0.56179 to 0.56033, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6371 - accuracy: 0.6988 - val_loss: 0.5603 - val_accuracy: 0.7840
# Epoch 81/500
# 33/48 [===================>..........] - ETA: 0s - loss: 0.6517 - accuracy: 0.6739
# Epoch 81: val_loss improved from 0.56033 to 0.55996, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6360 - accuracy: 0.6762 - val_loss: 0.5600 - val_accuracy: 0.7680
# Epoch 82/500
# 34/48 [====================>.........] - ETA: 0s - loss: 0.6445 - accuracy: 0.6759
# Epoch 82: val_loss improved from 0.55996 to 0.55850, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6296 - accuracy: 0.6796 - val_loss: 0.5585 - val_accuracy: 0.7760
# Epoch 83/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.6353 - accuracy: 0.6979
# Epoch 83: val_loss improved from 0.55850 to 0.55710, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6351 - accuracy: 0.6988 - val_loss: 0.5571 - val_accuracy: 0.7820
# Epoch 84/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.6337 - accuracy: 0.6966
# Epoch 84: val_loss improved from 0.55710 to 0.55556, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6338 - accuracy: 0.7000 - val_loss: 0.5556 - val_accuracy: 0.7840
# Epoch 85/500
# 40/48 [========================>.....] - ETA: 0s - loss: 0.6675 - accuracy: 0.6970
# Epoch 85: val_loss improved from 0.55556 to 0.55480, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6574 - accuracy: 0.6988 - val_loss: 0.5548 - val_accuracy: 0.7820
# Epoch 86/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.6081 - accuracy: 0.7111
# Epoch 86: val_loss improved from 0.55480 to 0.55472, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6095 - accuracy: 0.7083 - val_loss: 0.5547 - val_accuracy: 0.7660
# Epoch 87/500
# 42/48 [=========================>....] - ETA: 0s - loss: 0.6404 - accuracy: 0.7014
# Epoch 87: val_loss improved from 0.55472 to 0.55325, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6357 - accuracy: 0.6975 - val_loss: 0.5532 - val_accuracy: 0.7680
# Epoch 88/500
# 34/48 [====================>.........] - ETA: 0s - loss: 0.6021 - accuracy: 0.7065
# Epoch 88: val_loss improved from 0.55325 to 0.55170, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6114 - accuracy: 0.7021 - val_loss: 0.5517 - val_accuracy: 0.7700
# Epoch 89/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.6162 - accuracy: 0.6911
# Epoch 89: val_loss improved from 0.55170 to 0.55050, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6149 - accuracy: 0.6929 - val_loss: 0.5505 - val_accuracy: 0.7700
# Epoch 90/500
# 32/48 [===================>..........] - ETA: 0s - loss: 0.5994 - accuracy: 0.7081
# Epoch 90: val_loss improved from 0.55050 to 0.54890, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6101 - accuracy: 0.7142 - val_loss: 0.5489 - val_accuracy: 0.7820
# Epoch 91/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.6153 - accuracy: 0.7063
# Epoch 91: val_loss improved from 0.54890 to 0.54723, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6128 - accuracy: 0.7063 - val_loss: 0.5472 - val_accuracy: 0.7820
# Epoch 92/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.6209 - accuracy: 0.7143
# Epoch 92: val_loss improved from 0.54723 to 0.54548, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6079 - accuracy: 0.7208 - val_loss: 0.5455 - val_accuracy: 0.7840
# Epoch 93/500
# 34/48 [====================>.........] - ETA: 0s - loss: 0.6132 - accuracy: 0.7100
# Epoch 93: val_loss improved from 0.54548 to 0.54385, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 4ms/step - loss: 0.6182 - accuracy: 0.7117 - val_loss: 0.5439 - val_accuracy: 0.7840
# Epoch 94/500
# 45/48 [===========================>..] - ETA: 0s - loss: 0.6037 - accuracy: 0.6991
# Epoch 94: val_loss improved from 0.54385 to 0.54253, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6116 - accuracy: 0.6996 - val_loss: 0.5425 - val_accuracy: 0.7840
# Epoch 95/500
# 43/48 [=========================>....] - ETA: 0s - loss: 0.6238 - accuracy: 0.7195
# Epoch 95: val_loss improved from 0.54253 to 0.54195, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6195 - accuracy: 0.7200 - val_loss: 0.5420 - val_accuracy: 0.7700
# Epoch 96/500
# 32/48 [===================>..........] - ETA: 0s - loss: 0.5947 - accuracy: 0.7188
# Epoch 96: val_loss improved from 0.54195 to 0.54019, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6032 - accuracy: 0.7196 - val_loss: 0.5402 - val_accuracy: 0.7780
# Epoch 97/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.5919 - accuracy: 0.7137
# Epoch 97: val_loss improved from 0.54019 to 0.53821, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5990 - accuracy: 0.7138 - val_loss: 0.5382 - val_accuracy: 0.7840
# Epoch 98/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.6046 - accuracy: 0.7135
# Epoch 98: val_loss improved from 0.53821 to 0.53644, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6051 - accuracy: 0.7129 - val_loss: 0.5364 - val_accuracy: 0.7840
# Epoch 99/500
# 34/48 [====================>.........] - ETA: 0s - loss: 0.6086 - accuracy: 0.7076
# Epoch 99: val_loss improved from 0.53644 to 0.53459, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6154 - accuracy: 0.7067 - val_loss: 0.5346 - val_accuracy: 0.7840
# Epoch 100/500
# 32/48 [===================>..........] - ETA: 0s - loss: 0.5958 - accuracy: 0.7219
# Epoch 100: val_loss improved from 0.53459 to 0.53258, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5880 - accuracy: 0.7229 - val_loss: 0.5326 - val_accuracy: 0.7840
# Epoch 101/500
# 43/48 [=========================>....] - ETA: 0s - loss: 0.5881 - accuracy: 0.7298
# Epoch 101: val_loss improved from 0.53258 to 0.53046, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5942 - accuracy: 0.7287 - val_loss: 0.5305 - val_accuracy: 0.7840
# Epoch 102/500
# 43/48 [=========================>....] - ETA: 0s - loss: 0.5866 - accuracy: 0.7181
# Epoch 102: val_loss improved from 0.53046 to 0.52827, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5831 - accuracy: 0.7242 - val_loss: 0.5283 - val_accuracy: 0.7840
# Epoch 103/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.6108 - accuracy: 0.7303
# Epoch 103: val_loss improved from 0.52827 to 0.52604, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5956 - accuracy: 0.7371 - val_loss: 0.5260 - val_accuracy: 0.8000
# Epoch 104/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.5737 - accuracy: 0.7286
# Epoch 104: val_loss improved from 0.52604 to 0.52364, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5718 - accuracy: 0.7367 - val_loss: 0.5236 - val_accuracy: 0.8060
# Epoch 105/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.5881 - accuracy: 0.7357
# Epoch 105: val_loss improved from 0.52364 to 0.52162, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5874 - accuracy: 0.7371 - val_loss: 0.5216 - val_accuracy: 0.7840
# Epoch 106/500
# 32/48 [===================>..........] - ETA: 0s - loss: 0.6138 - accuracy: 0.7231
# Epoch 106: val_loss improved from 0.52162 to 0.51899, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.6148 - accuracy: 0.7312 - val_loss: 0.5190 - val_accuracy: 0.8020
# Epoch 107/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.5940 - accuracy: 0.7248
# Epoch 107: val_loss improved from 0.51899 to 0.51727, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5916 - accuracy: 0.7275 - val_loss: 0.5173 - val_accuracy: 0.8020
# Epoch 108/500
# 32/48 [===================>..........] - ETA: 0s - loss: 0.5764 - accuracy: 0.7344
# Epoch 108: val_loss improved from 0.51727 to 0.51446, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5751 - accuracy: 0.7412 - val_loss: 0.5145 - val_accuracy: 0.8060
# Epoch 109/500
# 32/48 [===================>..........] - ETA: 0s - loss: 0.5745 - accuracy: 0.7381
# Epoch 109: val_loss improved from 0.51446 to 0.51184, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5795 - accuracy: 0.7317 - val_loss: 0.5118 - val_accuracy: 0.8060
# Epoch 110/500
# 48/48 [==============================] - ETA: 0s - loss: 0.5751 - accuracy: 0.7450
# Epoch 110: val_loss improved from 0.51184 to 0.50906, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5751 - accuracy: 0.7450 - val_loss: 0.5091 - val_accuracy: 0.8060
# Epoch 111/500
# 38/48 [======================>.......] - ETA: 0s - loss: 0.5672 - accuracy: 0.7532
# Epoch 111: val_loss improved from 0.50906 to 0.50624, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 6ms/step - loss: 0.5651 - accuracy: 0.7475 - val_loss: 0.5062 - val_accuracy: 0.8060
# Epoch 112/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.5850 - accuracy: 0.7374
# Epoch 112: val_loss improved from 0.50624 to 0.50325, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5847 - accuracy: 0.7379 - val_loss: 0.5033 - val_accuracy: 0.8080
# Epoch 113/500
# 48/48 [==============================] - ETA: 0s - loss: 0.5682 - accuracy: 0.7629
# Epoch 113: val_loss improved from 0.50325 to 0.50069, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5682 - accuracy: 0.7629 - val_loss: 0.5007 - val_accuracy: 0.8080
# Epoch 114/500
# 33/48 [===================>..........] - ETA: 0s - loss: 0.5742 - accuracy: 0.7533
# Epoch 114: val_loss did not improve from 0.50069
# 48/48 [==============================] - 0s 4ms/step - loss: 0.5909 - accuracy: 0.7529 - val_loss: 0.5039 - val_accuracy: 0.7840
# Epoch 115/500
# 45/48 [===========================>..] - ETA: 0s - loss: 0.5565 - accuracy: 0.7342
# Epoch 115: val_loss did not improve from 0.50069
# 48/48 [==============================] - 0s 4ms/step - loss: 0.5631 - accuracy: 0.7342 - val_loss: 0.5028 - val_accuracy: 0.7840
# Epoch 116/500
# 33/48 [===================>..........] - ETA: 0s - loss: 0.5565 - accuracy: 0.7673
# Epoch 116: val_loss improved from 0.50069 to 0.50049, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5556 - accuracy: 0.7621 - val_loss: 0.5005 - val_accuracy: 0.7980
# Epoch 117/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.5698 - accuracy: 0.7604
# Epoch 117: val_loss improved from 0.50049 to 0.49814, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5679 - accuracy: 0.7621 - val_loss: 0.4981 - val_accuracy: 0.8020
# Epoch 118/500
# 43/48 [=========================>....] - ETA: 0s - loss: 0.5699 - accuracy: 0.7679
# Epoch 118: val_loss improved from 0.49814 to 0.49577, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5683 - accuracy: 0.7696 - val_loss: 0.4958 - val_accuracy: 0.8060
# Epoch 119/500
# 43/48 [=========================>....] - ETA: 0s - loss: 0.5630 - accuracy: 0.7460
# Epoch 119: val_loss did not improve from 0.49577
# 48/48 [==============================] - 0s 4ms/step - loss: 0.5629 - accuracy: 0.7458 - val_loss: 0.5038 - val_accuracy: 0.7660
# Epoch 120/500
# 43/48 [=========================>....] - ETA: 0s - loss: 0.5580 - accuracy: 0.7572
# Epoch 120: val_loss did not improve from 0.49577
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5547 - accuracy: 0.7575 - val_loss: 0.5043 - val_accuracy: 0.7820
# Epoch 121/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.5444 - accuracy: 0.7651
# Epoch 121: val_loss did not improve from 0.49577
# 48/48 [==============================] - 0s 4ms/step - loss: 0.5438 - accuracy: 0.7658 - val_loss: 0.5035 - val_accuracy: 0.7840
# Epoch 122/500
# 35/48 [====================>.........] - ETA: 0s - loss: 0.5445 - accuracy: 0.7691
# Epoch 122: val_loss did not improve from 0.49577
# 48/48 [==============================] - 0s 4ms/step - loss: 0.5598 - accuracy: 0.7592 - val_loss: 0.5027 - val_accuracy: 0.7840
# Epoch 123/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.5531 - accuracy: 0.7661
# Epoch 123: val_loss did not improve from 0.49577
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5543 - accuracy: 0.7646 - val_loss: 0.5019 - val_accuracy: 0.7840
# Epoch 124/500
# 41/48 [========================>.....] - ETA: 0s - loss: 0.5838 - accuracy: 0.7527
# Epoch 124: val_loss did not improve from 0.49577
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5767 - accuracy: 0.7542 - val_loss: 0.5012 - val_accuracy: 0.7840
# Epoch 125/500
# 45/48 [===========================>..] - ETA: 0s - loss: 0.5404 - accuracy: 0.7640
# Epoch 125: val_loss did not improve from 0.49577
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5412 - accuracy: 0.7621 - val_loss: 0.5004 - val_accuracy: 0.7840
# Epoch 126/500
# 48/48 [==============================] - ETA: 0s - loss: 0.5740 - accuracy: 0.7654
# Epoch 126: val_loss did not improve from 0.49577
# 48/48 [==============================] - 0s 4ms/step - loss: 0.5740 - accuracy: 0.7654 - val_loss: 0.4996 - val_accuracy: 0.7840
# Epoch 127/500
# 43/48 [=========================>....] - ETA: 0s - loss: 0.5662 - accuracy: 0.7656
# Epoch 127: val_loss did not improve from 0.49577
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5707 - accuracy: 0.7629 - val_loss: 0.4989 - val_accuracy: 0.7840
# Epoch 128/500
# 40/48 [========================>.....] - ETA: 0s - loss: 0.5386 - accuracy: 0.7740
# Epoch 128: val_loss did not improve from 0.49577
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5351 - accuracy: 0.7738 - val_loss: 0.4980 - val_accuracy: 0.7840
# Epoch 129/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.5554 - accuracy: 0.7574
# Epoch 129: val_loss did not improve from 0.49577
# 48/48 [==============================] - 0s 4ms/step - loss: 0.5552 - accuracy: 0.7546 - val_loss: 0.4970 - val_accuracy: 0.7840
# Epoch 130/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.5594 - accuracy: 0.7570
# Epoch 130: val_loss did not improve from 0.49577
# 48/48 [==============================] - 0s 4ms/step - loss: 0.5603 - accuracy: 0.7554 - val_loss: 0.4961 - val_accuracy: 0.7840
# Epoch 131/500
# 32/48 [===================>..........] - ETA: 0s - loss: 0.5616 - accuracy: 0.7794
# Epoch 131: val_loss improved from 0.49577 to 0.49525, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5660 - accuracy: 0.7704 - val_loss: 0.4953 - val_accuracy: 0.8040
# Epoch 132/500
# 39/48 [=======================>......] - ETA: 0s - loss: 0.5673 - accuracy: 0.7621
# Epoch 132: val_loss improved from 0.49525 to 0.49432, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 6ms/step - loss: 0.5663 - accuracy: 0.7625 - val_loss: 0.4943 - val_accuracy: 0.8060
# Epoch 133/500
# 45/48 [===========================>..] - ETA: 0s - loss: 0.5684 - accuracy: 0.7662
# Epoch 133: val_loss improved from 0.49432 to 0.49340, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5660 - accuracy: 0.7642 - val_loss: 0.4934 - val_accuracy: 0.8060
# Epoch 134/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.5506 - accuracy: 0.7694
# Epoch 134: val_loss improved from 0.49340 to 0.49267, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5541 - accuracy: 0.7675 - val_loss: 0.4927 - val_accuracy: 0.8060
# Epoch 135/500
# 48/48 [==============================] - ETA: 0s - loss: 0.5379 - accuracy: 0.7725
# Epoch 135: val_loss improved from 0.49267 to 0.49248, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5379 - accuracy: 0.7725 - val_loss: 0.4925 - val_accuracy: 0.8080
# Epoch 136/500
# 40/48 [========================>.....] - ETA: 0s - loss: 0.5505 - accuracy: 0.7650
# Epoch 136: val_loss improved from 0.49248 to 0.49166, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 6ms/step - loss: 0.5535 - accuracy: 0.7638 - val_loss: 0.4917 - val_accuracy: 0.8120
# Epoch 137/500
# 41/48 [========================>.....] - ETA: 0s - loss: 0.5263 - accuracy: 0.7829
# Epoch 137: val_loss improved from 0.49166 to 0.49069, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 6ms/step - loss: 0.5272 - accuracy: 0.7808 - val_loss: 0.4907 - val_accuracy: 0.8240
# Epoch 138/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.5615 - accuracy: 0.7719
# Epoch 138: val_loss improved from 0.49069 to 0.48972, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5613 - accuracy: 0.7713 - val_loss: 0.4897 - val_accuracy: 0.8260
# Epoch 139/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.5381 - accuracy: 0.7681
# Epoch 139: val_loss improved from 0.48972 to 0.48902, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5442 - accuracy: 0.7683 - val_loss: 0.4890 - val_accuracy: 0.8240
# Epoch 140/500
# 44/48 [==========================>...] - ETA: 0s - loss: 0.5397 - accuracy: 0.7645
# Epoch 140: val_loss improved from 0.48902 to 0.48790, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5366 - accuracy: 0.7658 - val_loss: 0.4879 - val_accuracy: 0.8260
# Epoch 141/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.5683 - accuracy: 0.7638
# Epoch 141: val_loss improved from 0.48790 to 0.48693, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5675 - accuracy: 0.7642 - val_loss: 0.4869 - val_accuracy: 0.8260
# Epoch 142/500
# 45/48 [===========================>..] - ETA: 0s - loss: 0.5495 - accuracy: 0.7831
# Epoch 142: val_loss improved from 0.48693 to 0.48600, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5469 - accuracy: 0.7829 - val_loss: 0.4860 - val_accuracy: 0.8260
# Epoch 143/500
# 44/48 [==========================>...] - ETA: 0s - loss: 0.5406 - accuracy: 0.7900
# Epoch 143: val_loss improved from 0.48600 to 0.48486, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5393 - accuracy: 0.7887 - val_loss: 0.4849 - val_accuracy: 0.8260
# Epoch 144/500
# 43/48 [=========================>....] - ETA: 0s - loss: 0.5442 - accuracy: 0.7642
# Epoch 144: val_loss improved from 0.48486 to 0.48368, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5422 - accuracy: 0.7658 - val_loss: 0.4837 - val_accuracy: 0.8260
# Epoch 145/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.5469 - accuracy: 0.7651
# Epoch 145: val_loss improved from 0.48368 to 0.48250, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5459 - accuracy: 0.7650 - val_loss: 0.4825 - val_accuracy: 0.8260
# Epoch 146/500
# 33/48 [===================>..........] - ETA: 0s - loss: 0.5355 - accuracy: 0.7715
# Epoch 146: val_loss improved from 0.48250 to 0.48124, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5470 - accuracy: 0.7733 - val_loss: 0.4812 - val_accuracy: 0.8260
# Epoch 147/500
# 45/48 [===========================>..] - ETA: 0s - loss: 0.5532 - accuracy: 0.7822
# Epoch 147: val_loss improved from 0.48124 to 0.47992, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5470 - accuracy: 0.7829 - val_loss: 0.4799 - val_accuracy: 0.8260
# Epoch 148/500
# 44/48 [==========================>...] - ETA: 0s - loss: 0.5597 - accuracy: 0.7591
# Epoch 148: val_loss improved from 0.47992 to 0.47860, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5524 - accuracy: 0.7646 - val_loss: 0.4786 - val_accuracy: 0.8260
# Epoch 149/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.5320 - accuracy: 0.7809
# Epoch 149: val_loss improved from 0.47860 to 0.47727, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5311 - accuracy: 0.7788 - val_loss: 0.4773 - val_accuracy: 0.8260
# Epoch 150/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.5446 - accuracy: 0.7826
# Epoch 150: val_loss improved from 0.47727 to 0.47589, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5453 - accuracy: 0.7804 - val_loss: 0.4759 - val_accuracy: 0.8280
# Epoch 151/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.5407 - accuracy: 0.7783
# Epoch 151: val_loss improved from 0.47589 to 0.47438, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5406 - accuracy: 0.7775 - val_loss: 0.4744 - val_accuracy: 0.8320
# Epoch 152/500
# ...
# Epoch 445/500
# 38/48 [======================>.......] - ETA: 0s - loss: 0.4738 - accuracy: 0.8711
# Epoch 445: val_loss did not improve from 0.22892
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4767 - accuracy: 0.8729 - val_loss: 0.2332 - val_accuracy: 0.9160
# Epoch 446/500
# 44/48 [==========================>...] - ETA: 0s - loss: 0.4902 - accuracy: 0.8791
# Epoch 446: val_loss did not improve from 0.22892
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4747 - accuracy: 0.8792 - val_loss: 0.2334 - val_accuracy: 0.9180
# Epoch 447/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.4914 - accuracy: 0.8689
# Epoch 447: val_loss did not improve from 0.22892
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4920 - accuracy: 0.8692 - val_loss: 0.2336 - val_accuracy: 0.9180
# Epoch 448/500
# 38/48 [======================>.......] - ETA: 0s - loss: 0.3371 - accuracy: 0.8679
# Epoch 448: val_loss did not improve from 0.22892
# 48/48 [==============================] - 0s 5ms/step - loss: 0.3632 - accuracy: 0.8696 - val_loss: 0.2343 - val_accuracy: 0.9180
# Epoch 449/500
# 39/48 [=======================>......] - ETA: 0s - loss: 0.4385 - accuracy: 0.8718
# Epoch 449: val_loss did not improve from 0.22892
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4352 - accuracy: 0.8725 - val_loss: 0.2333 - val_accuracy: 0.9180
# Epoch 450/500
# 37/48 [======================>.......] - ETA: 0s - loss: 0.4767 - accuracy: 0.8762
# Epoch 450: val_loss did not improve from 0.22892
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4579 - accuracy: 0.8725 - val_loss: 0.2319 - val_accuracy: 0.9180
# Epoch 451/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.4296 - accuracy: 0.8668
# Epoch 451: val_loss did not improve from 0.22892
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4265 - accuracy: 0.8679 - val_loss: 0.2324 - val_accuracy: 0.9180
# Epoch 452/500
# 44/48 [==========================>...] - ETA: 0s - loss: 0.4588 - accuracy: 0.8705
# Epoch 452: val_loss did not improve from 0.22892
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4517 - accuracy: 0.8687 - val_loss: 0.2334 - val_accuracy: 0.9180
# Epoch 453/500
# 48/48 [==============================] - ETA: 0s - loss: 0.5104 - accuracy: 0.8817
# Epoch 453: val_loss did not improve from 0.22892
# 48/48 [==============================] - 0s 6ms/step - loss: 0.5104 - accuracy: 0.8817 - val_loss: 0.2334 - val_accuracy: 0.9280
# Epoch 454/500
# 40/48 [========================>.....] - ETA: 0s - loss: 0.4628 - accuracy: 0.8735
# Epoch 454: val_loss did not improve from 0.22892
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4516 - accuracy: 0.8754 - val_loss: 0.2328 - val_accuracy: 0.9280
# Epoch 455/500
# 38/48 [======================>.......] - ETA: 0s - loss: 0.5068 - accuracy: 0.8763
# Epoch 455: val_loss did not improve from 0.22892
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4917 - accuracy: 0.8742 - val_loss: 0.2317 - val_accuracy: 0.9240
# Epoch 456/500
# 45/48 [===========================>..] - ETA: 0s - loss: 0.5075 - accuracy: 0.8733
# Epoch 456: val_loss did not improve from 0.22892
# 48/48 [==============================] - 0s 6ms/step - loss: 0.5036 - accuracy: 0.8725 - val_loss: 0.2333 - val_accuracy: 0.9240
# Epoch 457/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.4391 - accuracy: 0.8778
# Epoch 457: val_loss did not improve from 0.22892
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4380 - accuracy: 0.8779 - val_loss: 0.2315 - val_accuracy: 0.9320
# Epoch 458/500
# 43/48 [=========================>....] - ETA: 0s - loss: 0.4951 - accuracy: 0.8740
# Epoch 458: val_loss did not improve from 0.22892
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4919 - accuracy: 0.8763 - val_loss: 0.2348 - val_accuracy: 0.9320
# Epoch 459/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.4186 - accuracy: 0.8678
# Epoch 459: val_loss did not improve from 0.22892
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4172 - accuracy: 0.8692 - val_loss: 0.2338 - val_accuracy: 0.9320
# Epoch 460/500
# 37/48 [======================>.......] - ETA: 0s - loss: 0.3963 - accuracy: 0.8714
# Epoch 460: val_loss did not improve from 0.22892
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4297 - accuracy: 0.8717 - val_loss: 0.2324 - val_accuracy: 0.9300
# Epoch 461/500
# 41/48 [========================>.....] - ETA: 0s - loss: 0.4936 - accuracy: 0.8844
# Epoch 461: val_loss did not improve from 0.22892
# 48/48 [==============================] - 0s 5ms/step - loss: 0.5091 - accuracy: 0.8796 - val_loss: 0.2308 - val_accuracy: 0.9280
# Epoch 462/500
# 48/48 [==============================] - ETA: 0s - loss: 0.4579 - accuracy: 0.8717
# Epoch 462: val_loss did not improve from 0.22892
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4579 - accuracy: 0.8717 - val_loss: 0.2297 - val_accuracy: 0.9260
# Epoch 463/500
# 38/48 [======================>.......] - ETA: 0s - loss: 0.4884 - accuracy: 0.8800
# Epoch 463: val_loss improved from 0.22892 to 0.22837, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4969 - accuracy: 0.8804 - val_loss: 0.2284 - val_accuracy: 0.9320
# Epoch 464/500
# 45/48 [===========================>..] - ETA: 0s - loss: 0.5429 - accuracy: 0.8684
# Epoch 464: val_loss did not improve from 0.22837
# 48/48 [==============================] - 0s 6ms/step - loss: 0.5381 - accuracy: 0.8721 - val_loss: 0.2295 - val_accuracy: 0.9180
# Epoch 465/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.4925 - accuracy: 0.8848
# Epoch 465: val_loss improved from 0.22837 to 0.22793, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4916 - accuracy: 0.8850 - val_loss: 0.2279 - val_accuracy: 0.9180
# Epoch 466/500
# 44/48 [==========================>...] - ETA: 0s - loss: 0.4316 - accuracy: 0.8891
# Epoch 466: val_loss improved from 0.22793 to 0.22560, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4239 - accuracy: 0.8908 - val_loss: 0.2256 - val_accuracy: 0.9180
# Epoch 467/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.4881 - accuracy: 0.8778
# Epoch 467: val_loss improved from 0.22560 to 0.22464, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4942 - accuracy: 0.8767 - val_loss: 0.2246 - val_accuracy: 0.9180
# Epoch 468/500
# 48/48 [==============================] - ETA: 0s - loss: 0.5060 - accuracy: 0.8783
# Epoch 468: val_loss improved from 0.22464 to 0.22430, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 6ms/step - loss: 0.5060 - accuracy: 0.8783 - val_loss: 0.2243 - val_accuracy: 0.9220
# Epoch 469/500
# 48/48 [==============================] - ETA: 0s - loss: 0.4538 - accuracy: 0.8858
# Epoch 469: val_loss improved from 0.22430 to 0.22304, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4538 - accuracy: 0.8858 - val_loss: 0.2230 - val_accuracy: 0.9260
# Epoch 470/500
# 48/48 [==============================] - ETA: 0s - loss: 0.5040 - accuracy: 0.8833
# Epoch 470: val_loss improved from 0.22304 to 0.22107, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 6ms/step - loss: 0.5040 - accuracy: 0.8833 - val_loss: 0.2211 - val_accuracy: 0.9320
# Epoch 471/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.4286 - accuracy: 0.8835
# Epoch 471: val_loss improved from 0.22107 to 0.22018, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4222 - accuracy: 0.8825 - val_loss: 0.2202 - val_accuracy: 0.9320
# Epoch 472/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.4618 - accuracy: 0.8817
# Epoch 472: val_loss improved from 0.22018 to 0.21858, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4542 - accuracy: 0.8833 - val_loss: 0.2186 - val_accuracy: 0.9280
# Epoch 473/500
# 40/48 [========================>.....] - ETA: 0s - loss: 0.4577 - accuracy: 0.8790
# Epoch 473: val_loss improved from 0.21858 to 0.21752, saving model to food_quality.weights.best.h5
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4560 - accuracy: 0.8813 - val_loss: 0.2175 - val_accuracy: 0.9320
# Epoch 474/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.4786 - accuracy: 0.8715
# Epoch 474: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4880 - accuracy: 0.8708 - val_loss: 0.2315 - val_accuracy: 0.9160
# Epoch 475/500
# 48/48 [==============================] - ETA: 0s - loss: 0.4746 - accuracy: 0.8763
# Epoch 475: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4746 - accuracy: 0.8763 - val_loss: 0.2360 - val_accuracy: 0.9160
# Epoch 476/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.3680 - accuracy: 0.8804
# Epoch 476: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.3714 - accuracy: 0.8817 - val_loss: 0.2360 - val_accuracy: 0.9160
# Epoch 477/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.3974 - accuracy: 0.8752
# Epoch 477: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4004 - accuracy: 0.8733 - val_loss: 0.2350 - val_accuracy: 0.9160
# Epoch 478/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.4189 - accuracy: 0.8796
# Epoch 478: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4167 - accuracy: 0.8808 - val_loss: 0.2375 - val_accuracy: 0.9160
# Epoch 479/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.4456 - accuracy: 0.8723
# Epoch 479: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4436 - accuracy: 0.8721 - val_loss: 0.2385 - val_accuracy: 0.9180
# Epoch 480/500
# 45/48 [===========================>..] - ETA: 0s - loss: 0.4093 - accuracy: 0.8813
# Epoch 480: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4114 - accuracy: 0.8833 - val_loss: 0.2372 - val_accuracy: 0.9180
# Epoch 481/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.4697 - accuracy: 0.8809
# Epoch 481: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4781 - accuracy: 0.8817 - val_loss: 0.2358 - val_accuracy: 0.9180
# Epoch 482/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.4955 - accuracy: 0.8702
# Epoch 482: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4985 - accuracy: 0.8704 - val_loss: 0.2350 - val_accuracy: 0.9180
# Epoch 483/500
# 39/48 [=======================>......] - ETA: 0s - loss: 0.4204 - accuracy: 0.8805
# Epoch 483: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4234 - accuracy: 0.8842 - val_loss: 0.2339 - val_accuracy: 0.9180
# Epoch 484/500
# 41/48 [========================>.....] - ETA: 0s - loss: 0.3901 - accuracy: 0.8834
# Epoch 484: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 5ms/step - loss: 0.3886 - accuracy: 0.8858 - val_loss: 0.2331 - val_accuracy: 0.9180
# Epoch 485/500
# 39/48 [=======================>......] - ETA: 0s - loss: 0.4263 - accuracy: 0.8703
# Epoch 485: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4326 - accuracy: 0.8700 - val_loss: 0.2322 - val_accuracy: 0.9180
# Epoch 486/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.3879 - accuracy: 0.8813
# Epoch 486: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.3854 - accuracy: 0.8813 - val_loss: 0.2312 - val_accuracy: 0.9180
# Epoch 487/500
# 44/48 [==========================>...] - ETA: 0s - loss: 0.4671 - accuracy: 0.8745
# Epoch 487: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4625 - accuracy: 0.8721 - val_loss: 0.2319 - val_accuracy: 0.9160
# Epoch 488/500
# 48/48 [==============================] - ETA: 0s - loss: 0.3978 - accuracy: 0.8804
# Epoch 488: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 5ms/step - loss: 0.3978 - accuracy: 0.8804 - val_loss: 0.2308 - val_accuracy: 0.9160
# Epoch 489/500
# 45/48 [===========================>..] - ETA: 0s - loss: 0.4246 - accuracy: 0.8733
# Epoch 489: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4501 - accuracy: 0.8712 - val_loss: 0.2297 - val_accuracy: 0.9160
# Epoch 490/500
# 46/48 [===========================>..] - ETA: 0s - loss: 0.4628 - accuracy: 0.8783
# Epoch 490: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4679 - accuracy: 0.8800 - val_loss: 0.2280 - val_accuracy: 0.9160
# Epoch 491/500
# 43/48 [=========================>....] - ETA: 0s - loss: 0.3834 - accuracy: 0.8800
# Epoch 491: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4048 - accuracy: 0.8788 - val_loss: 0.2267 - val_accuracy: 0.9180
# Epoch 492/500
# 44/48 [==========================>...] - ETA: 0s - loss: 0.4727 - accuracy: 0.8727
# Epoch 492: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4816 - accuracy: 0.8733 - val_loss: 0.2256 - val_accuracy: 0.9180
# Epoch 493/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.4480 - accuracy: 0.8749
# Epoch 493: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4495 - accuracy: 0.8754 - val_loss: 0.2240 - val_accuracy: 0.9180
# Epoch 494/500
# 44/48 [==========================>...] - ETA: 0s - loss: 0.4551 - accuracy: 0.8800
# Epoch 494: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4590 - accuracy: 0.8800 - val_loss: 0.2227 - val_accuracy: 0.9180
# Epoch 495/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.4543 - accuracy: 0.8715
# Epoch 495: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4577 - accuracy: 0.8721 - val_loss: 0.2216 - val_accuracy: 0.9180
# Epoch 496/500
# 41/48 [========================>.....] - ETA: 0s - loss: 0.4876 - accuracy: 0.8878
# Epoch 496: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4873 - accuracy: 0.8817 - val_loss: 0.2263 - val_accuracy: 0.9160
# Epoch 497/500
# 44/48 [==========================>...] - ETA: 0s - loss: 0.4689 - accuracy: 0.8773
# Epoch 497: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4782 - accuracy: 0.8754 - val_loss: 0.2262 - val_accuracy: 0.9160
# Epoch 498/500
# 45/48 [===========================>..] - ETA: 0s - loss: 0.4599 - accuracy: 0.8698
# Epoch 498: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4608 - accuracy: 0.8700 - val_loss: 0.2247 - val_accuracy: 0.9160
# Epoch 499/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.4207 - accuracy: 0.8826
# Epoch 499: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4261 - accuracy: 0.8804 - val_loss: 0.2223 - val_accuracy: 0.9180
# Epoch 500/500
# 47/48 [============================>.] - ETA: 0s - loss: 0.4340 - accuracy: 0.8791
# Epoch 500: val_loss did not improve from 0.21752
# 48/48 [==============================] - 0s 6ms/step - loss: 0.4386 - accuracy: 0.8783 - val_loss: 0.2217 - val_accuracy: 0.9240

# %%
#Get history
history_dict = history.history
history_dict.keys()

#dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])
import matplotlib.pyplot as plt

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
#Evaluate model with the test set
print(len(test_features))
scores = model.evaluate(test_features, test_targets_categorical, verbose=1)
print('Test accuracy:', scores)
# Out:
# 100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1870 - accuracy: 0.9900
# Test accuracy: [0.18697071075439453, 0.9900000095367432]

# %%
#Evaluate model with the test set
test_features = np.array(test_features_list[22])
test_features = np.expand_dims(test_features, axis=0)
print(test_features)
score = model.predict(test_features, verbose=1)
print(score)
print(tf.math.argmax(score[0]))
# Out:
# [[0.02443793 0.11241447 0.01564027 0.0173998  0.01857283 0.028348
#   0.02639296 0.01935484]]
# 1/1 [==============================] - 0s 19ms/step
# [[ 0.02451167 -0.01545153]]
# tf.Tensor(0, shape=(), dtype=int64)

# %% [markdown]
# ##Reconstruct the model from the .h5 format

# %%
reconstructed_model = keras.models.load_model("/content/food_quality.weights.best.h5")

# %%
#Evaluate the reconstructed model with the test set
score = reconstructed_model.predict(test_features, verbose=1)
print(score)
print(tf.math.argmax(score[0]))
# Out:
# 1/1 [==============================] - 0s 20ms/step
# [[ 0.02394055 -0.01535104]]
# tf.Tensor(0, shape=(), dtype=int64)

# %%
reconstructed_model.save('/content/saved_model')
# Out:
# INFO:tensorflow:Assets written to: /content/saved_model/assets

# %% [markdown]
# ##Convert to tflite

# %%
# Convert the model
converter = tf.lite.TFLiteConverter.from_saved_model('/content/saved_model') # path to the SavedModel directory
tflite_model = converter.convert()

# Save the model.
with open('food_model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded

# %%
# Load the TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path="/content/food_model.tflite")
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
print(input_details)
print(output_details)

interpreter.set_tensor(input_details[0]['index'], tf.cast(test_features, tf.float32))

interpreter.invoke()

# The function `get_tensor()` returns a copy of the tensor data.
# Use `tensor()` in order to get a pointer to the tensor.
output_data = interpreter.get_tensor(output_details[0]['index'])
print(output_data)
# Out:
# [{'name': 'serving_default_dense_input:0', 'index': 0, 'shape': array([1, 8], dtype=int32), 'shape_signature': array([-1,  8], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# [{'name': 'StatefulPartitionedCall:0', 'index': 12, 'shape': array([1, 2], dtype=int32), 'shape_signature': array([-1,  2], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# [[ 0.02394055 -0.01535105]]
